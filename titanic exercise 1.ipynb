# %%
import pandas as pd

# %%
# Case 1
## mengakses data penumpang kapal
titanic_data = pd.read_csv('titanic.csv')

titanic_data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# case 1.1
# tampilkan data 10 penumpang yg ada ditabel

titanic_data.head(10) # cara 1
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
titanic_data.iloc[:10] # cara 2
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
# case 1.2
# tampilkan informasi nama, umur, tiket, dan fare dari 10 penumpang terakhir yg ada didalam table
titanic_data.tail(10)[['Name', 'Age', 'Ticket', 'Fare']] # cara 1
# Out:
#                                          Name   Age            Ticket     Fare
# 881                        Markun, Mr. Johann  33.0            349257   7.8958
# 882              Dahlberg, Miss. Gerda Ulrika  22.0              7552  10.5167
# 883             Banfield, Mr. Frederick James  28.0  C.A./SOTON 34068  10.5000
# 884                    Sutehall, Mr. Henry Jr  25.0   SOTON/OQ 392076   7.0500
# 885      Rice, Mrs. William (Margaret Norton)  39.0            382652  29.1250
# 886                     Montvila, Rev. Juozas  27.0            211536  13.0000
# 887              Graham, Miss. Margaret Edith  19.0            112053  30.0000
# 888  Johnston, Miss. Catherine Helen "Carrie"   NaN        W./C. 6607  23.4500
# 889                     Behr, Mr. Karl Howell  26.0            111369  30.0000
# 890                       Dooley, Mr. Patrick  32.0            370376   7.7500

# %%
titanic_data.iloc[:10,[3,5,8,9]]
# Out:
#                                                 Name   Age            Ticket  \
# 0                            Braund, Mr. Owen Harris  22.0         A/5 21171
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0          PC 17599
# 2                             Heikkinen, Miss. Laina  26.0  STON/O2. 3101282
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0            113803
# 4                           Allen, Mr. William Henry  35.0            373450
# 5                                   Moran, Mr. James   NaN            330877
# 6                            McCarthy, Mr. Timothy J  54.0             17463
# 7                     Palsson, Master. Gosta Leonard   2.0            349909
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  27.0            347742
# 9                Nasser, Mrs. Nicholas (Adele Achem)  14.0            237736
#
#       Fare
# 0   7.2500
# 1  71.2833
# 2   7.9250
# 3  53.1000
# 4   8.0500
# 5   8.4583
# 6  51.8625
# 7  21.0750
# ...

# %%
# case 1.3
# tampilkan informasi survived hingga ticket dari penumpang yang bernama Braund, Mr. Owen Harris,
# Heikkinen, Miss. Laina, dan Markun, Mr. Johann

titanic_data1 = titanic_data.set_index('Name') # menjadikan kolom nama sbg index
titanic_data1
# Out:
#                                                     PassengerId  Survived  \
# Name
# Braund, Mr. Owen Harris                                       1         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss. Laina                                        3         1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4         1
# Allen, Mr. William Henry                                      5         0
# ...                                                         ...       ...
# Montvila, Rev. Juozas                                       887         0
# Graham, Miss. Margaret Edith                                888         1
# Johnston, Miss. Catherine Helen "Carrie"                    889         0
# Behr, Mr. Karl Howell                                       890         1
# Dooley, Mr. Patrick                                         891         0
#
# ...

# %%
# memanggil nama dan kolom yg diinginkan dari PassngerId hingga ticket
titanic_data1.loc[['Braund, Mr. Owen Harris', 'Heikkinen, Miss. Laina', 'Markun, Mr. Johann'], 'PassengerId':'Ticket']
# Out:
#                          PassengerId  Survived  Pclass     Sex   Age  SibSp  \
# Name
# Braund, Mr. Owen Harris            1         0       3    male  22.0      1
# Heikkinen, Miss. Laina             3         1       3  female  26.0      0
# Markun, Mr. Johann               882         0       3    male  33.0      0
#
#                          Parch            Ticket
# Name
# Braund, Mr. Owen Harris      0         A/5 21171
# Heikkinen, Miss. Laina       0  STON/O2. 3101282
# Markun, Mr. Johann           0            349257

# %%
# 1.4
# menampilkan informasi Age, Ticket, dan Embarked dari penumpang yang bernama Heikkinen, Miss. Laina hingga Palsson, Master. Gosta Leonard
titanic_data1.loc['Heikkinen, Miss. Laina':'Palsson, Master. Gosta Leonard', ['Age','Ticket','Embarked']]
# Out:
#                                                Age            Ticket Embarked
# Name
# Heikkinen, Miss. Laina                        26.0  STON/O2. 3101282        S
# Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0            113803        S
# Allen, Mr. William Henry                      35.0            373450        S
# Moran, Mr. James                               NaN            330877        Q
# McCarthy, Mr. Timothy J                       54.0             17463        S
# Palsson, Master. Gosta Leonard                 2.0            349909        S

# %%
# Exercise
# no.1 ubah index menjadi kolom passengerId tanpa menghilangkan kolom nama
# reset index
titanic_data.reset_index(inplace=True)

# set passengerId sebagain index
titanic_data.set_index('PassengerId')
# Out:
#              index  Survived  Pclass  \
# PassengerId
# 1                0         0       3
# 2                1         1       1
# 3                2         1       3
# 4                3         1       1
# 5                4         0       3
# ...            ...       ...     ...
# 887            886         0       2
# 888            887         1       1
# 889            888         0       3
# 890            889         1       1
# 891            890         0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...

# %%
# no2. Tampilkan data penumpang yg memiliki id 29,78, dan 66
titanic_data.loc[[29, 78, 66]]
# Out:
#     index  PassengerId  Survived  Pclass                           Name  \
# 29     29           30         0       3            Todoroff, Mr. Lalio
# 78     78           79         1       2  Caldwell, Master. Alden Gates
# 66     66           67         1       2   Nye, Mrs. (Elizabeth Ramell)
#
#        Sex    Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# 29    male    NaN      0      0      349216   7.8958   NaN        S
# 78    male   0.83      0      2      248738  29.0000   NaN        S
# 66  female  29.00      0      0  C.A. 29395  10.5000   F33        S

# %%
# 3.Tampilkan informasi penumpang yang memiliki id 40-50 dan tampilkan infoemasi Name, Sibsp, dan Parch
titanic_data.loc[40:50, ['Name', 'SibSp', 'Parch']] # cara 1
# Out:
#                                                  Name  SibSp  Parch
# 40     Ahlin, Mrs. Johan (Johanna Persdotter Larsson)      1      0
# 41  Turpin, Mrs. William John Robert (Dorothy Ann ...      1      0
# 42                                Kraeff, Mr. Theodor      0      0
# 43           Laroche, Miss. Simonne Marie Anne Andree      1      2
# 44                      Devaney, Miss. Margaret Delia      0      0
# 45                           Rogers, Mr. William John      0      0
# 46                                  Lennon, Mr. Denis      1      0
# 47                          O'Driscoll, Miss. Bridget      0      0
# 48                                Samaan, Mr. Youssef      2      0
# 49      Arnold-Franchi, Mrs. Josef (Josefine Franchi)      1      0
# 50                         Panula, Master. Juha Niilo      4      1

# %%
titanic_data.loc[40:50, 'Name':'Parch']
# Out:
#                                                  Name     Sex   Age  SibSp  \
# 40     Ahlin, Mrs. Johan (Johanna Persdotter Larsson)  female  40.0      1
# 41  Turpin, Mrs. William John Robert (Dorothy Ann ...  female  27.0      1
# 42                                Kraeff, Mr. Theodor    male   NaN      0
# 43           Laroche, Miss. Simonne Marie Anne Andree  female   3.0      1
# 44                      Devaney, Miss. Margaret Delia  female  19.0      0
# 45                           Rogers, Mr. William John    male   NaN      0
# 46                                  Lennon, Mr. Denis    male   NaN      1
# 47                          O'Driscoll, Miss. Bridget  female   NaN      0
# 48                                Samaan, Mr. Youssef    male   NaN      2
# 49      Arnold-Franchi, Mrs. Josef (Josefine Franchi)  female  18.0      1
# 50                         Panula, Master. Juha Niilo    male   7.0      4
#
#     Parch
# 40      0
# 41      0
# 42      0
# 43      2
# ...

# %%
# 4. Tampilkan informasi ticket dari penumpang dengan id 887
titanic_data.loc[887,'Ticket']
# Out:
# '112053'

# %%
# 5. Kembalikan index ke bentuk defaultnya (index awal)
titanic_data.reset_index(inplace = True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3832\801118579.py in ?()
#       1 # 5. Kembalikan index ke bentuk defaultnya (index awal)
# ----> 2 titanic_data.reset_index(inplace = True)
#       3
#
# ~\anaconda3\Lib\site-packages\pandas\core\frame.py in ?(self, level, drop, inplace, col_level, col_fill, allow_duplicates, names)
#    6468                     level_values = algorithms.take(
#    6469                         level_values, lab, allow_fill=True, fill_value=lev._na_value
#    6470                     )
#    6471
# -> 6472                 new_obj.insert(
#    6473                     0,
#    6474                     name,
#    6475                     level_values,
#
# ~\anaconda3\Lib\site-packages\pandas\core\frame.py in ?(self, loc, column, value, allow_duplicates)
# ...

# %%
titanic_data
# Out:
#      level_0  index  PassengerId  Survived  Pclass  \
# 0          0      0            1         0       3
# 1          1      1            2         1       1
# 2          2      2            3         1       3
# 3          3      3            4         1       1
# 4          4      4            5         0       3
# ..       ...    ...          ...       ...     ...
# 886      886    886          887         0       2
# 887      887    887          888         1       1
# 888      888    888          889         0       3
# 889      889    889          890         1       1
# 890      890    890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# ...
